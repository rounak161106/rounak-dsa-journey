# %% [markdown]
# Efficient communication -
# - Direct communication uses 0 and 1. for 26 alphabets, we can use fixed length encoding scheme which means to take 5 bits. But can we do something more efficient. because some bits are wasted and we have to send large bits of data even for the letters which are less frequently used.
# - We have variable length encoding, morse code
